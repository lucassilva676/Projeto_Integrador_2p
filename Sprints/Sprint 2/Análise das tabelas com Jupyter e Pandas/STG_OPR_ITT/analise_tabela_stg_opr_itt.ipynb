# %% [markdown]
# **Ánalise da tabela 'STG_OPR_ITT' ou Tabela de Operação**

# %%
#importando a biblioteca necessária
import pandas as pd

# %%
ler = pd.read_excel('STG_OPR_ITT.xlsx')

# %%
ler.head(10)
# Out:
#    ID_STG_OPR_ITT  VLR_CTRD_CSC  QTD_PCL  VLR_SDO_DDR  QTD_CLI_CAD_POS  \
# 0               1           NaN       45          NaN              341
# 1               2           NaN       63          NaN              103
# 2               3           NaN       22          NaN               15
# 3               4           NaN       48          NaN                9
# 4               5           NaN      290          NaN                3
# 5               6           NaN      109          NaN                1
# 6               7    24231168.0       20   14774641.0                6
# 7               8           NaN       59          NaN              235
# 8               9           NaN       38          NaN               14
# 9              10           NaN      117          NaN                4
#
#    QTD_OPR  ID_FNT_ITT ID_MDL DES_TIP_PSS DAT_RSS_FNT_ITT  \
# 0      358          67    A04           F      2020-01-16
# 1      108          67    B99           F      2020-01-16
# ...

# %%
ler.dtypes
# Out:
# ID_STG_OPR_ITT       int64
# VLR_CTRD_CSC        object
# QTD_PCL             object
# VLR_SDO_DDR        float64
# QTD_CLI_CAD_POS     object
# QTD_OPR              int64
# ID_FNT_ITT           int64
# ID_MDL              object
# DES_TIP_PSS         object
# DAT_RSS_FNT_ITT     object
# DAT_INC_DBO         object
# QTD_OPR             object
# dtype: object

# %%
ler['VLR_CTRD_CSC'] = ler.VLR_CTRD_CSC.astype('str')
ler['QTD_PCL'] = ler.QTD_PCL.astype('str')
ler['VLR_SDO_DDR'] = ler.VLR_SDO_DDR.astype('str')
ler['QTD_CLI_CAD_POS'] = ler.QTD_CLI_CAD_POS.astype('str')
ler['QTD_OPR'] = ler.QTD_OPR.astype('str')

# %%
ler.dtypes
# Out:
# ID_STG_OPR_ITT      int64
# VLR_CTRD_CSC       object
# QTD_PCL            object
# VLR_SDO_DDR        object
# QTD_CLI_CAD_POS    object
# QTD_OPR            object
# ID_FNT_ITT          int64
# ID_MDL             object
# DES_TIP_PSS        object
# DAT_RSS_FNT_ITT    object
# DAT_INC_DBO        object
# QTD_OPR            object
# dtype: object

# %%
ler.to_csv('stg_opr_itt.csv', index=False, header=True)
